# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(0,50,50)
y = np.random.randint(0,100,50)
color = np.random.randint(10,100,50)
size = np.random.randint(10,40,50)

plt.scatter(x,y,marker="*", cmap="hot",c=color,s=size)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_excel("D:/DataAnalytics/dataset for pandas/ESD.xlsx")
df = pd.DataFrame(data)
print(df)
plt.scatter(df["Annual Salary"],df["EEID"], s = df["Age"])
plt.show()
# Out:
#        EEID        Full Name  ...       City  Exit Date
# 0    E02387      Emily Davis  ...    Seattle 2021-10-16
# 1    E04105    Theodore Dinh  ...  Chongqing        NaT
# 2    E02572     Luna Sanders  ...    Chicago        NaT
# 3    E02832  Penelope Jordan  ...    Chicago        NaT
# 4    E01639        Austin Vo  ...    Phoenix        NaT
# ..      ...              ...  ...        ...        ...
# 995  E03094     Wesley Young  ...   Columbus        NaT
# 996  E01909     Lillian Khan  ...    Chengdu 2018-01-08
# 997  E04398      Oliver Yang  ...      Miami        NaT
# 998  E02521      Lily Nguyen  ...    Chengdu        NaT
# 999  E03545      Sofia Cheng  ...      Miami        NaT
#
# [1000 rows x 14 columns]

# %%
brands = ["Oneplus","Apple","Samaung","Nokia","Redmi"]
x = [22,35,30,3,10]
c = ["blue","purple","Gold","red","green"]
ex = [0,0,0,0,0.1]
plt.pie(x, labels = brands,colors = c,explode=ex, shadow=True,autopct="%.2f", startangle=45)
plt.show()

# %%
data = pd.read_excel("D:/DataAnalytics/dataset for pandas/ESD.xlsx")
df = pd.DataFrame(data)
grouped_by = df.groupby("Country")["Annual Salary"].sum()
plt.pie(grouped_by.values, labels = grouped_by.values , shadow=True,autopct="%.2f", startangle=45)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# %%
l = [25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55,78]
print(min(l))
print(max(l))
plt.boxplot(l)
plt.show()
# Out:
# 6
# 99

# %%
l = [25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55,78]
l1= [2,3,4,5,6,7,8,9,1,10,11,8,6,8,10,11,12,18,15,25,22,41,66]
print(len(l))
print(len(l1))
plot_values =[l,l1]
plt.boxplot(plot_values)
plt.show()
# Out:
# 20
# 23

# %%
import pandas as pd

# %%
data = pd.read_excel("D:/DataAnalytics/dataset for pandas/ESD.xlsx")
df = pd.DataFrame(data)
# grouped_by = df.groupby("Age")["Annual Salary"].sum()
# print(grouped_by)
plt.boxplot(df["Annual Salary"])
plt.show()

# %%
import matplotlib.pyplot as plt

x = [30,40,68,27,47,59,47,88,44,23,44,66,33,66,5,2,5,50]
plt.hist(x, bins = len(x), edgecolor ="black",color = "purple")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel('D:/DataAnalytics/dataset for pandas/ESD.xlsx')
df = pd.DataFrame(data)
grouped_by = df.groupby("Department")["Annual Salary"].sum()
#grouped_by = df.groupby("Country")["Annual Salary"].sum()
print(grouped_by)
plt.hist(grouped_by, bins = 20)
plt.show()
# Out:
# Department
# Accounting         11822107
# Engineering        17227563
# Finance            14736347
# Human Resources    14757305
# IT                 23567499
# Marketing          15559564
# Sales              15546980
# Name: Annual Salary, dtype: int64

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {"Days": [1,2,3,4,5],
       "NOP": [50,40,60,30,44]}
print(df)
df = pd.DataFrame(data)
sns.lineplot(data= data , x ="Days", y ="NOP")
plt.show()
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   30
# 3     4   60
# 4     5   44

# %%
data = pd.read_excel('D:/DataAnalytics/dataset for pandas/ESD.xlsx')
df = pd.DataFrame(data)
print(df)
color = sns.color_palette("viridis")
sns.lineplot(data = df, x= "Business Unit", y="Age",hue="Ethnicity",style="Gender",palette=color)
plt.show()
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
sns.barplot(data = df, x ="Country", y = "Bonus %")
plt.show()

# %%
data = pd.read_excel('D:/DataAnalytics/dataset for pandas/ESD.xlsx')
# data = sns.load_dataset('ESD')
sns.histplot(data,x="Business Unit", hue= 'Gender', kde =True)
plt.show()

# %%
data = sns.load_dataset('titanic')
print(data)
sns.histplot(data,x="age", hue= 'who', kde =True, discrete=True)
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data= sns.load_dataset("tips")
print(data)
sns.scatterplot(data,x="total_bill", y ="tip", hue = 'day', size="size",marker="o",palette="viridis")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = sns.load_dataset("tips")
print(data)
gp = data.groupby("day").agg({"tip":"mean"})
sns.heatmap(gp)
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...
